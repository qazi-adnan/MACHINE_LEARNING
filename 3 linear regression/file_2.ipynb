# %% [markdown]
# # SIMPLE LINEAR RGERESSION MODEL FOR UNDERSTANDING MATHS

# %% [markdown]
# 20,000 points based on the equation
#               𝑦=0.983𝑥1+2.3473
# ​

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"D:\STUDY\MACHINE_LEARNING\3 linear regression\random_values_y.csv")

# %%
df
# Out:
#              x1          y
# 0      3.745401   6.029029
# 1      9.507143  11.692822
# 2      7.319939   9.542800
# 3      5.986585   8.232113
# 4      1.560186   3.880963
# ...         ...        ...
# 19995  8.770386  10.968590
# 19996  0.468140   2.807481
# 19997  3.036985   5.332656
# 19998  4.433200   6.705136
# 19999  1.722648   4.040663
#
# [20000 rows x 2 columns]

# %%
df.dtypes
# Out:
# x1    float64
# y     float64
# dtype: object

# %%
x=df["x1"]
y=df["y"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.2,random_state=42)

# %%
x_train = pd.DataFrame(x_train)  # Convert Series to DataFrame

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([0.983])

# %%
regression.intercept_
# Out:
# np.float64(2.347299999999999)

# %%
x_test = pd.DataFrame(x_test)  # Convert Series to DataFrame

# %%
y_pred=regression.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)

# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

score=r2_score(y_test,y_pred)
# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R_squar score is :{score}")
# Out:
# Mean Absolute Error (MAE): 8.98586760555986e-16
# Mean Squared Error (MSE): 1.5910708160725604e-30
# Root Mean Squared Error (RMSE): 1.2613765560182893e-15
# R_squar score is :1.0

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train_scaled,y_train)
print(regression.coef_)
print(regression.intercept_)
# Out:
# [2.84391679]
# 7.2457434905413685

# %%
y_pred=regression.predict(x_test_scaled)

# %%
#Calculate MAE
mae = mean_absolute_error(y_test, y_pred)

# Calculate MSE
mse = mean_squared_error(y_test, y_pred)

# Calculate RMSE
rmse = np.sqrt(mse)

score=r2_score(y_test,y_pred)
# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R_squar score is :{score}")
# Out:
# Mean Absolute Error (MAE): 1.1697032231694493e-15
# Mean Squared Error (MSE): 2.4443471445855254e-30
# Root Mean Squared Error (RMSE): 1.5634408030320578e-15
# R_squar score is :1.0
